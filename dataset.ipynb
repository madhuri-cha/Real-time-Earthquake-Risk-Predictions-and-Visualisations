# %%
import json

with open("earthquake_data.json","r") as file :
    apiData = json.load(file)

# %%
data = {
    "mag" : [],
    "place" : [],
    "time" : [],
    "updated" : [],
    "tz" : [],
    "url": [],
    "detail" : [],
    'felt': [],
    'cdi': [],
    'mmi': [],
    'alert': [],
    'status': [],
    'tsunami': [],
    'sig': [],
    'net': [],
    'code': [],
    'ids': [],
    "sources": [],
    "types": [],
    "nst": [],
    "dmin": [],
    "rms": [],
    "gap": [],
    "magType": [],
    "type": [],
    "title": [],
    "type": []
}

# %%
for j in apiData:
    for i in j["features"]:
        data["mag"].append(i["properties"]["mag"])
        data["place"].append(i["properties"]["place"]),
        data["time"].append(i["properties"]["time"]),
        data["updated"].append(i["properties"]["updated"]),
        data["tz"].append(i["properties"]["tz"]),
        data["url"].append(i["properties"]["url"]),
        data["detail"].append(i["properties"]["detail"]),
        data['felt'].append(i["properties"]["felt"]),
        data['cdi'].append(i["properties"]["cdi"]),
        data['mmi'].append(i["properties"]["mmi"]),
        data['alert']. append(i["properties"]["alert"]),
        data['status'].append(i["properties"]["status"]),
        data['tsunami'].append(i["properties"]["tsunami"]),
        data['sig'].append(i["properties"]["sig"]),
        data['net'].append(i["properties"]["net"]),
        data['code'].append(i["properties"]["code"]),
        data['ids'].append(i["properties"]["ids"]),
        data["sources"].append(i["properties"]["sources"]),
        data["types"].append(i["properties"]["types"]),
        data["nst"].append(i["properties"]["nst"]),
        data["dmin"].append(i["properties"]["dmin"]),
        data["rms"].append(i["properties"]["rms"]),
        data["gap"].append(i["properties"]["gap"]),
        data["magType"].append(i["properties"]["magType"]),
        data["type"].append(i["properties"]["type"]),
        data["title"].append(i["properties"]["title"]),

# %%
length = { key : len(value) for key,value in data.items()}

# %%
length
# Out:
# {'mag': 2949298,
#  'place': 2949298,
#  'time': 2949298,
#  'updated': 2949298,
#  'tz': 2949298,
#  'url': 2949298,
#  'detail': 2949298,
#  'felt': 2949298,
#  'cdi': 2949298,
#  'mmi': 2949298,
#  'alert': 2949298,
#  'status': 2949298,
#  'tsunami': 2949298,
#  'sig': 2949298,
#  'net': 2949298,
#  'code': 2949298,
#  'ids': 2949298,
#  'sources': 2949298,
#  'types': 2949298,
#  'nst': 2949298,
#  'dmin': 2949298,
#  'rms': 2949298,
#  'gap': 2949298,
#  'magType': 2949298,
#  'type': 2949298,
#  'title': 2949298}

# %%
dataFrame = pd.DataFrame(data)

# %%
dataFrame.to_csv("earthquake.csv")

# %%
dataFrame
# Out:
#           mag                                            place           time  \
# 0        0.60                      31 km NNE of Beatty, Nevada   949362720619
# 1        1.72         26km NNW of Twentynine Palms, California   949362294060
# 2        2.10  12 km NNW of Sangre Grande, Trinidad and Tobago   949361318420
# 3        2.10                    22 km NNE of Meeker, Colorado   949360395860
# 4        4.50                18 km SSW of Montecristi, Ecuador   949359922010
# ...       ...                                              ...            ...
# 2949293  1.40                     2 km ESE of Big Lake, Alaska  1733098200376
# 2949294  1.80                   25 km SW of Larsen Bay, Alaska  1733098143738
# 2949295  3.50            Rat Islands, Aleutian Islands, Alaska  1733098078836
# 2949296  0.85                 3 km WSW of Anderson Springs, CA  1733097915510
# 2949297  0.39                         23 km W of Sitka, Alaska  1733097667040
#
# ...

# %%
apiData[0]["features"][0]["properties"]["mag"]
# Out:
# 0.6

# %%
import pandas as pd

# %%
for i in data:
    print(len(i))
# Out:
# 3
# 5
# 4
# 7
# 2
# 3
# 6
# 4
# 3
# 3
# 5
# 6
# 7
# 3
# 3
# 4
# 3
# 7
# 5
# 3
# 4
# 3
# 3
# 7
# 4
# 5
# 11

# %%
dataframe = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dataframe = pd.DataFrame(data)
#
# File c:\Users\dumbr\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
#     769     from numpy.ma import mrecords
#
# ...
